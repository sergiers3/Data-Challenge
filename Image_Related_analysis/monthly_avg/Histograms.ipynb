# %%
import pandas as pd

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Dinther.csv', sep=";", dtype={ "Value": float})

# %%
df["TimeStamp"] = pd.to_datetime(df["TimeStamp"])

# %%
df.dtypes
# Out:
# Area_Name            object
# Tag Name             object
# TimeStamp    datetime64[ns]
# Value               float64
# dtype: object

# %%
df.index = df["TimeStamp"]

# %%
del df["Area_Name"]

# %%
del df["Tag Name"]

# %%
del df["TimeStamp"]

# %%
df2 = df.resample('M').mean()

# %%
df2.to_csv("/Users/sergiers/Desktop/Dinther_month.csv", sep=',')

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 14
fig_size[1] = 7

# %% [markdown]
# ### Create histograms foreach region

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Dinther.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 


#Histogram monthly and hourly
dinther = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
dinther.plot(kind="bar", title="Average monthly flow in Dinther")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Aarle.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 
#Histogram monthly and hourly
aarle = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
aarle.plot(kind="bar", title="Average monthly flow in Aarle")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Vinkel.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 

#Histogram monthly and hourly
vinkel = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
vinkel.plot(kind="bar", title="Average monthly flow in Vinkel")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Oijen.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 

#Histogram monthly and hourly
oijen = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
oijen.plot(kind="bar", title="Average monthly flow in Oijen")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Land_van_Cuijk_1.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 

#Histogram monthly and hourly
lvc1 = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
lvc1.plot(kind="bar", title="Average monthly flow in Land_van_Cuijk_1")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/CleanDataset/data_wwtp_all_flow_1.5years/Same_data_but_separated_by_regions/Land_van_Cuijk_2.csv',delimiter=";",parse_dates=[2],date_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y %H:%M:%S')) 

#Histogram monthly and hourly
lvc2 = df.iloc[:,[2,3]].groupby(df["TimeStamp"].dt.month).mean()
lvc2.plot(kind="bar", title="Average monthly flow in Land_van_Cuijk_2")

# %%
#Read CSV
df = pd.read_csv('/Users/sergiers/Desktop/Den_Bosch.csv',parse_dates=[0],date_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')) 

#Histogram monthly and hourly
db = df.iloc[:,[0,1]].groupby(df["TimeStamp"].dt.month).mean()
db.plot(kind="bar", title="Average monthly flow in Den_Bosch")

# %% [markdown]
# ### Create boxplots foreach region

# %% [markdown]
# ### Create final histogram comparing several regions

# %%
plt.figure()

fig_size[0] = 22
fig_size[1] = 12



dbp = db.plot()
lvc1p = lvc1.plot(ax=dbp)
lvc2p = lvc2.plot(ax=lvc1p)
dintherp = dinther.plot(ax=lvc2p)
aarlep = aarle.plot(ax=dintherp)
vinkelp = vinkel.plot(ax=aarlep)
oijenp = oijen.plot(ax=vinkelp)

lvc2p.legend(labels=["Den Bosch", "Land Van Cuijk 1", "Land Van Cuijk 2", "dinther", "Aarle", "Vinkel", "Oijen"])
